# %% [markdown]
# ### Рассмотрим данные
# как их будем предобрабатывать перез загрузкой в векторную базу

# %%
import sys
sys.path.append('..')

from scripts.process_yandex_ml import process_all_files

# %% [markdown]
# ### 1. ds_questions

# %% [markdown]
# ### 2. education.yandex.ru
# В качестве данных вытсупает учебник по машинному обучению

# %%
process_all_files(
    input_dir='../raw_data/education.yandex.ru/ml',
    output_file='../processed_data/yandex_ml_vectors.json',
    description='Материалы курса Яндекс по машинному обучению'
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 process_all_files(
#       2     input_dir='../raw_data/education.yandex.ru/ml',
#       3     output_file='../processed_data/yandex_ml_vectors.json',
#       4     description='Материалы курса Яндекс по машинному обучению'
#       5 )
#
# TypeError: process_all_files() got an unexpected keyword argument 'description'

# %% [markdown]
# ### 3. huggingface

# %% [markdown]
# ### 4. huggingface

# %% [markdown]
# ### 4. huggingface
